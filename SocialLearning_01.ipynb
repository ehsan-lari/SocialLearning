# %% [markdown]
# <a href="https://colab.research.google.com/github/ehsan-lari/SocialLearning/blob/main/SocialLearning_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
T_MAX = 100
MU_0 = torch.Tensor([1/3, 1/3, 1/3])
MU = MU_0
N_STATES = len(MU_0)
MU_TEMP = torch.zeros(N_STATES)
V = torch.Tensor([1/2, 1, 3/2])
MU_ALL = torch.zeros(T_MAX, N_STATES)

# %%
for t in range(T_MAX):
    MU_ALL[t, :] = MU
    x = torch.randn(1) + torch.Tensor([0.6])
    for n in range(N_STATES):
        MU_TEMP[n] = MU[n] * torch.exp( - ( x - V[n] )**2 / 2 ) / torch.sum( MU*torch.exp( - ( x*torch.ones(N_STATES) - V )**2 /2 ) )
    MU = MU_TEMP

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 6))
plt.plot(MU_ALL.detach().numpy()[:,0], linewidth = 2, color= 'blue', label = 'mu1')
plt.plot(MU_ALL.detach().numpy()[:,1], linewidth = 2, color= 'red', label = 'mu2')
plt.plot(MU_ALL.detach().numpy()[:,2], linewidth = 2, color= 'green', label = 'mu3')
plt.grid(axis='both')
plt.xlabel('t')
plt.ylabel('MU')
plt.legend()
plt.show()
